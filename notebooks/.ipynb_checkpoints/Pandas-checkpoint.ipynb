# %%
## Pandas

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': 'John',
    'Sex': 'male',
    'Age': 22
}

# %%
pd.Series(data)
# Out:
# Name    John
# Sex     male
# Age       22
# dtype: object

# %%
### Numpy

# %%
# NumPyArrayから作成
array = np.array([22,31,42,23])
age_series = pd.Series(array)
# → NumpyArrayでは Keyがないためindexが作成される

# %%
array = np.array(['John', 'male',23])
john_series = pd.Series(array, index=['Name', 'Sex', 'Age'])

# %%
john_series['Name']
# Out:
# 'John'

# %%
# memo

# %%
age_series.values
# Out:
# array([22, 31, 42, 23])

# %%
age_series.mean()
# Out:
# 29.5
